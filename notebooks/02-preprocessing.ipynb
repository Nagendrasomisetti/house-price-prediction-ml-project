# %%
import pandas as pd
df = pd.read_csv(r"E:\Nagendra\projects\house-price-prediction-ml-project\data\Housing.csv")
print(df.shape)
df.head()
# Out:
# (4600, 18)
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
df.drop(['date','street','country'],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# city             0
# statezip         0
# dtype: int64

# %%
df['yr_renovated'] = df['yr_renovated'].apply(lambda x:1 if x!=0 else 0)

# %%
df = pd.get_dummies(df,columns = ['city','statezip'],drop_first=True)

# %%
df.head(1)
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  313000.0       3.0        1.5         1340      7912     1.5           0
#
#    view  condition  sqft_above  ...  statezip_WA 98155  statezip_WA 98166  \
# 0     0          3        1340  ...              False              False
#
#    statezip_WA 98168  statezip_WA 98177  statezip_WA 98178  statezip_WA 98188  \
# 0              False              False              False              False
#
#    statezip_WA 98198  statezip_WA 98199  statezip_WA 98288  statezip_WA 98354
# 0              False              False              False              False
#
# [1 rows x 132 columns]

# %%
df.to_csv(r"E:\Nagendra\projects\house-price-prediction-ml-project\data\Housing_cleaned.csv", index=False)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()
